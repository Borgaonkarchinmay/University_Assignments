# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.histplot(df["fare"])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.scatterplot(data=df, x = "fare", y="pclass", hue="sex")
# Out:
# <AxesSubplot:xlabel='fare', ylabel='pclass'>

# %%
sns.lineplot(data=df, x="pclass", y="alive")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='alive'>

# %%
sns.barplot(data = df, x = "pclass", y="age", hue="alive")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.swarmplot(data = df, x="pclass", y="fare", hue="alone")
# Out:
# /home/pict/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 36.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/pict/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 69.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/pict/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 84.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='pclass', ylabel='fare'>

# %%
sns.histplot(data=df, x="pclass", hue="alive", multiple="stack")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='Count'>

# %%
sns.boxplot(data=df, x="alive", y="fare", hue="sex")
# Out:
# <AxesSubplot:xlabel='alive', ylabel='fare'>

# %%
sns.violinplot(data=df, x="class", y="age", hue="alone", cut=0)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.pointplot(data=df, x="class", y="age", hue="alive")
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>
